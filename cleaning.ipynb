# %% [markdown]
# # Cleaning check_dates csv for getting high count sitters

# %%
import pandas as pd
import re

# %%
#import check_dates csv
check_dates_df = pd.read_csv('check_dates.csv')

# %%
#remove sitters with "unidentified" in Sitter column
check_dates_df = check_dates_df[~check_dates_df['Sitter'].str.contains('unidentified', flags=re.IGNORECASE, na=False)]
# also, remove (Multiple Portraits)     
check_dates_df = check_dates_df[~check_dates_df['Sitter'].str.contains('\(Multiple Portraits\)', flags=re.IGNORECASE, na=False)]    

#get high count sitters
sitter_counts = check_dates_df['Sitter'].value_counts()

# %%
pd.set_option('display.max_rows', None)
sitter_counts

# %%
#keep sitters with more than 3 entries
high_count_sitters = sitter_counts[sitter_counts > 3].index.tolist()
high_count_sitters_df = check_dates_df[check_dates_df['Sitter'].isin(high_count_sitters)]

# %%
high_count_sitters_df = high_count_sitters_df.reset_index(drop=True)
high_count_sitters_df.head()
#drop Unnamed columns
# Out:
#    Unnamed: 0                                     collectionsURL unitCode  \
# 0           0  https://collections.si.edu/search/detail/edanm...     SAAM
# 1           3  https://collections.si.edu/search/detail/edanm...     SAAM
# 2          23  https://collections.si.edu/search/detail/edanm...     SAAM
# 3          29  https://collections.si.edu/search/detail/edanm...     SAAM
# 4          97  https://collections.si.edu/search/detail/edanm...     SAAM
#
#                    EDANurl                                          title  \
# 0      edanmdm:saam_XX108A                              George Washington
# 1   edanmdm:saam_2014.29.1  Thomas Jefferson Presidential Inaugural Medal
# 2  edanmdm:saam_1999.27.58                              John Quincy Adams
# 3  edanmdm:saam_1999.27.41                    Major-General Anthony Wayne
# 4    edanmdm:saam_1971.111           Mourning Piece for George Washington
#
#                                           creditLine  \
# 0  {"Credit Line": "Smithsonian American Art Muse...
# 1  {"Credit Line": "Smithsonian American Art Muse...
# 2  {"Credit Line": "Smithsonian American Art Muse...
# 3  {"Credit Line": "Smithsonian American Art Muse...
# 4  {"Credit Line": "Smithsonian American Art Muse...
#
#                              date                       identifier  \
# 0               {"Date": "1803?"}      {"Object number": "XX108A"}
# 1                {"Date": "1801"}   {"Object number": "2014.29.1"}
# 2  {"Date": "early 19th century"}  {"Object number": "1999.27.58"}
# 3            {"Date": "ca. 1795"}  {"Object number": "1999.27.41"}
# 4                {"Date": "1810"}    {"Object number": "1971.111"}
#
#                                                 name  \
# 0  {"Attributed to": "William Winstanley, born En...
# 1  {"Engraver": "John Reich, born Furth, Germany ...
# 2  {"Artist": "Unidentified", "Sitter": "John Qui...
# 3  {"Artist": "James Peale, born Chestertown, MD ...
# 4  {"Artist": "Enoch G. Gridley, active 1803-1818...
#
#                                                notes  ...  indexed_places  \
# 0                                                NaN  ...             NaN
# 1                                                NaN  ...             NaN
# 2  {"Luce Center Label": "Son of John and Abigail...  ...             NaN
# 3  {"Luce Center Label": "\u201cMad Anthony\u201d...  ...             NaN
# 4                                                NaN  ...  ["Washington"]
#
#                                       indexed_topics mediaCount  \
# 0  ["Occupations", "Men", "Portraits", "Political...          1
# 1  ["Occupations", "Men", "Portraits", "Political...          1
# 2                               ["Men", "Portraits"]          1
# 3  ["Uniforms", "Occupations", "Clothing and dres...          1
# 4  ["Soldiers", "Memorials", "Occupations", "Men"...          1
#
#                                            mediaURLs  \
# 0  ["https://ids.si.edu/ids/deliveryService?id=SA...
# 1  ["https://ids.si.edu/ids/deliveryService?id=SA...
# 2  ["https://ids.si.edu/ids/deliveryService?id=SA...
# 3  ["https://ids.si.edu/ids/deliveryService?id=SA...
# 4  ["https://ids.si.edu/ids/deliveryService?id=SA...
#
#                                            thumbnail             Sitter  \
# 0  https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...  George Washington
# 1  https://ids.si.edu/ids/iiif/SAAM-2014.29.1_1/f...   Thomas Jefferson
# 2  https://ids.si.edu/ids/iiif/SAAM-1999.27.58_1/...  John Quincy Adams
# 3  https://ids.si.edu/ids/iiif/SAAM-1999.27.41_1/...      Anthony Wayne
# 4  https://ids.si.edu/ids/iiif/SAAM-1971.111_1/fu...  George Washington
#
#                Artist Clean_Date Gender Occupation
# 0  William Winstanley       1803    Men        NaN
# 1          John Reich       1801    Men        NaN
# 2        Unidentified         19    Men        NaN
# 3         James Peale       1795    Men        NaN
# 4    Enoch G. Gridley       1810    Men        NaN
#
# [5 rows x 28 columns]

# %%
#export
high_count_sitters_df.to_csv('high_count_sitters.csv', index=False)
